# %%
#imports
import pandas as pd
import seaborn as sns
import statsmodels.formula.api as smf
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.cross_validation import train_test_split
import numpy as np

#allow plots to appear directly in the notebook
# %matplotlib inline

# %%
#read data into a DataFrame
data = pd.read_csv('http://www-bcf.usc.edu/~gareth/ISL/Advertising.csv', index_col=0)
data.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 1  230.1   37.8       69.2   22.1
# 2   44.5   39.3       45.1   10.4
# 3   17.2   45.9       69.3    9.3
# 4  151.5   41.3       58.5   18.5
# 5  180.8   10.8       58.4   12.9

# %%
#print the shape of the DataFrame
data.shape
# Out:
# (200, 4)

# %%
#visualize the relatioinship between the features and the response using scatterplots
sns.pairplot(data, x_vars=['TV','Radio','Newspaper'], y_vars='Sales', size=7, aspect=0.7)

# %%
###STATSMODELS###

#create a fitted model
lm1 = smf.ols(formula = 'Sales ~ TV',data = data).fit()

#print the coefficients
lm1.params
# Out:
# Intercept    7.032594
# TV           0.047537
# dtype: float64

# %%
### SCIKIT-LEARN ###

# create X and y
feature_cols = ['TV']
X = data[feature_cols]
y = data.Sales

#instantiate and fit
lm2 = LinearRegression()
lm2.fit(X,y)

#print the coefficients
print lm2.intercept_
print lm2.coef_
# Out:
# 7.03259354913
# [ 0.04753664]

# %%
#manually calculate prediction for 50k TV spend
7.032594 + 0.047537*50
# Out:
# 9.409444

# %%
### STATSMODELS ###

#you have to create a DataFrame since the Statsmodels formula interface expects it
X_new = pd.DataFrame({'TV':[50]})

# predict for a new observation
lm1.predict(X_new)
# Out:
# array([ 9.40942557])

# %%
### SCIKIT-LEARN ###

#predict for a new observation
lm2.predict(50)
# Out:
# array([ 9.40942557])

# %%
sns.pairplot(data,x_vars=['TV','Radio','Newspaper'],y_vars='Sales',size=7,aspect=0.7,kind='reg')

# %%
### STATSMODELS ###

#print the confidence intervals for the model coefficients
lm1.conf_int()
# Out:
#                   0         1
# Intercept  6.129719  7.935468
# TV         0.042231  0.052843

# %%
### STATS MODELS ###

# print the p-values for the model coefficients
lm1.pvalues
# Out:
# Intercept    1.406300e-35
# TV           1.467390e-42
# dtype: float64

# %%
### STATSMODELS ###

# print the R-sqaured value for the model
lm1.rsquared
# Out:
# 0.61187505085007099

# %%
### SCIKIT-LEARN ###

#print the R-squared value for the model
lm2.score(X,y)
# Out:
# 0.61187505085007099

# %%
### STATSMODELS ###

# create a fitted model with all three features
lm1 = smf.ols(formula='Sales ~ TV + Radio + Newspaper',data = data).fit()

#print the coefficients
lm1.params
# Out:
# Intercept    2.938889
# TV           0.045765
# Radio        0.188530
# Newspaper   -0.001037
# dtype: float64

# %%
### SCIKIT-LEARN ###
# create X and y
feature_cols = ['TV','Radio','Newspaper']
X = data[feature_cols]
y = data.Sales

#instantiate and fit
lm2 = LinearRegression()
lm2.fit(X,y)

#print the coefficients
print lm2.intercept_
print lm2.coef_
# Out:
# 2.93888936946
# [ 0.04576465  0.18853002 -0.00103749]

# %%
# pair the feature names with the coefficients
zip(feature_cols, lm2.coef_)
# Out:
# [('TV', 0.04576464545539765),
#  ('Radio', 0.18853001691820462),
#  ('Newspaper', -0.0010374930424762799)]

# %%
### STATSMODELS ###

#print a summary of the fitted model
lm1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Sales   R-squared:                       0.897
# Model:                            OLS   Adj. R-squared:                  0.896
# Method:                 Least Squares   F-statistic:                     570.3
# Date:                Sat, 19 Sep 2015   Prob (F-statistic):           1.58e-96
# Time:                        10:56:45   Log-Likelihood:                -386.18
# No. Observations:                 200   AIC:                             780.4
# Df Residuals:                     196   BIC:                             793.6
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      2.9389      0.312      9.422      0.000         2.324     3.554
# TV             0.0458      0.001     32.809      0.000         0.043     0.049
# Radio          0.1885      0.009     21.893      0.000         0.172     0.206
# Newspaper     -0.0010      0.006     -0.177      0.860        -0.013     0.011
# ==============================================================================
# Omnibus:                       60.414   Durbin-Watson:                   2.084
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              151.241
# Skew:                          -1.327   Prob(JB):                     1.44e-33
# Kurtosis:                       6.332   Cond. No.                         454.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
### STATSMODELS ###

# only include TV and Radio in the model
lm1 = smf.ols(formula='Sales ~ TV + Radio',data =data).fit()
lm1.rsquared
# Out:
# 0.89719426108289557

# %%
# add Newspaper to the model (which we believe has no association with the data)
lm1 = smf.ols(formula='Sales ~ TV + Radio + Newspaper',data=data).fit()
lm1.rsquared
# Out:
# 0.89721063817895219

# %%
# define true and predicted response values
y_true = [100,50,30,20]
y_pred = [90,50,50,30]

#calculate MAE, MSE, RMSE
print metrics.mean_absolute_error(y_true, y_pred)
print metrics.mean_squared_error(y_true, y_pred)
print np.sqrt(metrics.mean_squared_error(y_true,y_pred))
# Out:
# 10.0
# 150.0
# 12.2474487139

# %%
# include Newspaper
X = data[['TV', 'Radio', 'Newspaper']]
y = data.Sales
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)
lm2 = LinearRegression()
lm2.fit(X_train, y_train)
y_pred = lm2.predict(X_test)
print np.sqrt(metrics.mean_squared_error(y_test, y_pred))
# Out:
# 1.40465142303

# %%
# exclude Newspaper
X = data[['TV', 'Radio']]
y = data.Sales
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)
lm2 = LinearRegression()
lm2.fit(X_train, y_train)
y_pred = lm2.predict(X_test)
print np.sqrt(metrics.mean_squared_error(y_test, y_pred))
# Out:
# 1.38790346994

# %%
#set a seed for repoducibility
np.random.seed(12345)

#create a series of booleans in which roughly half are True
nums = np.random.rand(len(data))
mask_large = nums > 0.5

#initially set size to small, then change roughly half to be large
data['Size'] = 'small'
data.loc[mask_large,'Size'] = 'large'
data.head()
# Out:
#       TV  Radio  Newspaper  Sales   Size
# 1  230.1   37.8       69.2   22.1  large
# 2   44.5   39.3       45.1   10.4  small
# 3   17.2   45.9       69.3    9.3  small
# 4  151.5   41.3       58.5   18.5  small
# 5  180.8   10.8       58.4   12.9  large

# %%
#create a new Series called Size_large
data['Size_large'] = data.Size.map({'small':0,'large':1})
data.head()
# Out:
#       TV  Radio  Newspaper  Sales   Size  Size_large
# 1  230.1   37.8       69.2   22.1  large           1
# 2   44.5   39.3       45.1   10.4  small           0
# 3   17.2   45.9       69.3    9.3  small           0
# 4  151.5   41.3       58.5   18.5  small           0
# 5  180.8   10.8       58.4   12.9  large           1

# %%
# create X and y
feature_cols = ['TV', 'Radio', 'Newspaper', 'Size_large']
X = data[feature_cols]
y = data.Sales

# instantiate, fit
lm2 = LinearRegression()
lm2.fit(X, y)

# print coefficients
zip(feature_cols, lm2.coef_)
# Out:
# [('TV', 0.045719820924362803),
#  ('Radio', 0.18872814313427874),
#  ('Newspaper', -0.0010976794483515545),
#  ('Size_large', 0.057423850854828061)]

# %%
# set a sedd for reproducibility
np.random.seed(123456)

#assign roughly one third of boservations to each group
nums = np.random.rand(len(data))
mask_suburban = (nums > 0.33) & (nums < 0.66)
mask_urban = nums > 0.66
data['Area'] = 'rural'
data.loc[mask_suburban, 'Area'] = 'suburban'
data.loc[mask_urban, 'Area'] = 'urban'
data.head()
# Out:
#       TV  Radio  Newspaper  Sales   Size  Size_large      Area
# 1  230.1   37.8       69.2   22.1  large           1     rural
# 2   44.5   39.3       45.1   10.4  small           0     urban
# 3   17.2   45.9       69.3    9.3  small           0     rural
# 4  151.5   41.3       58.5   18.5  small           0     urban
# 5  180.8   10.8       58.4   12.9  large           1  suburban

# %%
# create three dummy variables using get_dummies
pd.get_dummies(data.Area, prefix='Area').head()
# Out:
#    Area_rural  Area_suburban  Area_urban
# 1           1              0           0
# 2           0              0           1
# 3           1              0           0
# 4           0              0           1
# 5           0              1           0

# %%
# create three dummy variables using get_dummies, then exclude the first dummy column
area_dummies = pd.get_dummies(data.Area, prefix='Area').iloc[:,1:]
area_dummies.head()
# Out:
#    Area_suburban  Area_urban
# 1              0           0
# 2              0           1
# 3              0           0
# 4              0           1
# 5              1           0

# %%
# concatenate the dummy variable columns onto the DataFrame (axis=0 means rows, axis=1 means columns)
data = pd.concat([data,area_dummies],axis=1)
data.head()
# Out:
#       TV  Radio  Newspaper  Sales   Size  Size_large      Area  Area_suburban  \
# 1  230.1   37.8       69.2   22.1  large           1     rural              0
# 2   44.5   39.3       45.1   10.4  small           0     urban              0
# 3   17.2   45.9       69.3    9.3  small           0     rural              0
# 4  151.5   41.3       58.5   18.5  small           0     urban              0
# 5  180.8   10.8       58.4   12.9  large           1  suburban              1
#
#    Area_urban
# 1           0
# 2           1
# 3           0
# 4           1
# 5           0

# %%
# create X and y
feature_cols = ['TV', 'Radio', 'Newspaper', 'Size_large', 'Area_suburban', 'Area_urban']
X = data[feature_cols]
y = data.Sales

# instantiate and fit
lm2 = LinearRegression()
lm2.fit(X, y)

# print the coefficients
zip(feature_cols, lm2.coef_)
# Out:
# [('TV', 0.04574401036331379),
#  ('Radio', 0.18786669552525814),
#  ('Newspaper', -0.0010876977267108706),
#  ('Size_large', 0.077396607497479411),
#  ('Area_suburban', -0.10656299015958708),
#  ('Area_urban', 0.26813802165220019)]

# %%
# create X and y
feature_cols = ['TV', 'Radio', 'Newspaper', 'Size_large', 'Area_suburban', 'Area_urban']
X = data[feature_cols]
y = data.Sales

# instantiate and fit
lm2 = LinearRegression()
lm2.fit(X, y)

# print the coefficients
zip(feature_cols, lm2.coef_)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-55-d49403e98ba6> in <module>()
#       6 # instantiate and fit
#       7 lm2 = LinearRegression()
# ----> 8 lm2.fit(X, y)
#       9
#      10 # print the coefficients
#
# C:\Users\Michael\Anaconda\lib\site-packages\sklearn\linear_model\base.py in fit(self, X, y, n_jobs)
#     374             n_jobs_ = self.n_jobs
#     375         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 376                          y_numeric=True, multi_output=True)
#     377
#     378         X, y, X_mean, y_mean, X_std = self._center_data(
#
# C:\Users\Michael\Anaconda\lib\site-packages\sklearn\utils\validation.pyc in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric)
#     442     X = check_array(X, accept_sparse, dtype, order, copy, force_all_finite,
#     443                     ensure_2d, allow_nd, ensure_min_samples,
# --> 444                     ensure_min_features)
#     445     if multi_output:
#     446         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# C:\Users\Michael\Anaconda\lib\site-packages\sklearn\utils\validation.pyc in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features)
#     350                              array.ndim)
#     351         if force_all_finite:
# --> 352             _assert_all_finite(array)
#     353
#     354     shape_repr = _shape_repr(array.shape)
#
# C:\Users\Michael\Anaconda\lib\site-packages\sklearn\utils\validation.pyc in _assert_all_finite(X)
#      50             and not np.isfinite(X).all()):
#      51         raise ValueError("Input contains NaN, infinity"
# ---> 52                          " or a value too large for %r." % X.dtype)
#      53
#      54
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %%
lm2.summary
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-65-87d990b02821> in <module>()
# ----> 1 lm2.summary
#
# AttributeError: 'LinearRegression' object has no attribute 'summary'
